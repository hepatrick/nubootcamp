# %% [markdown]
# ## WeatherPy - Xuan He
# -----
# Summary of data analysis :
# Three observations from the weather data plots of 500 randomly selected cities are:
#
# 1. The temperature is highest near latitude zero (the equator), and decreases away from latitude zero in both directions (North & South).During the end of the calendar year, i.e., November, the temperature is cooler in the Northern hemisphere, where latitudes are greater than 0 and the temperature is warmer in the Southern hemisphere, where latitudes are less than 0.
# 2. There is no regional correlation to % cloudiness or % humidity.
# 3. The majority of wind speed is less than 15 mph.
# 4. There was no relationship between latitude and humidity, cloudiness and wind speed. However, the data suggest that there are more cities with a relative humidity greater than 50% and wind speed less than 15 mph, which would be an interesting analysis. The majority of the cities generated are in the Northern hemisphere.

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from datetime import datetime
from random import uniform
from config import api_key

# Create a df to lat, lon 
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)

# %% [markdown]
# ## Generate Cites List from Lats and Longs

# %%
# Randomly generate a list of 1750 cities. Use 50 to test for duplicates.
for x in range(1750):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)

#Remove duplicate cities
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      689
# City       689
# Country    689
# dtype: int64

# %% [markdown]
# ## Perform API Calls

# %%
#Create a df to add all the data from the API calls.
column_names = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
clean_cities_df = pd.DataFrame(columns=column_names)

# Loop through the list of cities and add the data to the df.
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        clean_cities_df.set_value(index, "City", city_data["name"])
        clean_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        clean_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        clean_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        clean_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        clean_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        clean_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        clean_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# ------------------------
# Proceesing: City #  1  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ushuaia
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  2  |  Vestmannaeyjar IS
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vestmannaeyjar
# ------------------------
# Proceesing: City #  3  |  Lazaro Cardenas MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lazaro+cardenas
# ------------------------
# Proceesing: City #  4  |  Gravdal NO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=gravdal
# ------------------------
# Proceesing: City #  5  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  6  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  7  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  8  |  Salalah OM
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=salalah
# ------------------------
# Proceesing: City #  9  |  Zitsa GR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=zitsa
# ------------------------
# Proceesing: City #  10  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=torbay
# ------------------------
# Proceesing: City #  11  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  12  |  Nadym RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nadym
# ------------------------
# Proceesing: City #  13  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  14  |  Longyearbyen NO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=longyearbyen
# ------------------------
# Proceesing: City #  15  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mar+del+plata
# City not found, skipping...
# ------------------------
# Proceesing: City #  16  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  17  |  Camacupa AO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=camacupa
# ------------------------
# Proceesing: City #  18  |  Moerai PF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=moerai
# ------------------------
# Proceesing: City #  19  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  20  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=severo-kurilsk
# City not found, skipping...
# ------------------------
# Proceesing: City #  21  |  Yomou GN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=yomou
# ------------------------
# Proceesing: City #  22  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  23  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  24  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  25  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  26  |  Kamenka RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kamenka
# ------------------------
# Proceesing: City #  27  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: City #  28  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  29  |  Gat SN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=gat
# ------------------------
# Proceesing: City #  30  |  Vila Velha BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vila+velha
# ------------------------
# Proceesing: City #  31  |  Flinders AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=flinders
# City not found, skipping...
# ------------------------
# Proceesing: City #  32  |  Nelson Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nelson+bay
# ------------------------
# Proceesing: City #  33  |  Karratha AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=karratha
# ------------------------
# Proceesing: City #  34  |  Pevek RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=pevek
# ------------------------
# Proceesing: City #  35  |  Vysokogornyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vysokogornyy
# ------------------------
# Proceesing: City #  36  |  Samarai PG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=samarai
# ------------------------
# Proceesing: City #  37  |  Kruisfontein ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kruisfontein
# ------------------------
# Proceesing: City #  38  |  Meulaboh ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=meulaboh
# ------------------------
# Proceesing: City #  39  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: City #  40  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  41  |  Ardakan IR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ardakan
# ------------------------
# Proceesing: City #  42  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=geraldton
# ------------------------
# Proceesing: City #  43  |  Raudeberg NO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=raudeberg
# ------------------------
# Proceesing: City #  44  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  45  |  Dourbali TD
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=dourbali
# ------------------------
# Proceesing: City #  46  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  47  |  Nowa Sol PL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nowa+sol
# City not found, skipping...
# ------------------------
# Proceesing: City #  48  |  Toufen TW
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=toufen
# ------------------------
# Proceesing: City #  49  |  Mount Gambier AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mount+gambier
# ------------------------
# Proceesing: City #  50  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  51  |  Itoman JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=itoman
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  52  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: City #  53  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  54  |  Lakes Entrance AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lakes+entrance
# ------------------------
# Proceesing: City #  55  |  Faanui PF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=faanui
# ------------------------
# Proceesing: City #  56  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  57  |  Slavjanovo BG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=slavjanovo
# ------------------------
# Proceesing: City #  58  |  Honiara SB
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=honiara
# ------------------------
# Proceesing: City #  59  |  Wagar US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=wagar
# ------------------------
# Proceesing: City #  60  |  Staraya Poltavka RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=staraya+poltavka
# ------------------------
# Proceesing: City #  61  |  Redmond US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=redmond
# ------------------------
# Proceesing: City #  62  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  63  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  64  |  Santa Cruz US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=santa+cruz
# ------------------------
# Proceesing: City #  65  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  66  |  Ostersund SE
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ostersund
# ------------------------
# Proceesing: City #  67  |  Hobyo SO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hobyo
# ------------------------
# Proceesing: City #  68  |  Katsuura JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=katsuura
# ------------------------
# Proceesing: City #  69  |  Cockburn Town TC
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=cockburn+town
# ------------------------
# Proceesing: City #  70  |  Sarangani PH
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sarangani
# ------------------------
# Proceesing: City #  71  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  72  |  Nepa Nagar IN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nepa+nagar
# ------------------------
# Proceesing: City #  73  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  74  |  Yeppoon AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=yeppoon
# City not found, skipping...
# ------------------------
# Proceesing: City #  75  |  Souillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=souillac
# ------------------------
# Proceesing: City #  76  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=cherskiy
# ------------------------
# Proceesing: City #  77  |  Jacksonville US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=jacksonville
# ------------------------
# Proceesing: City #  78  |  Newcastle ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=newcastle
# City not found, skipping...
# ------------------------
# Proceesing: City #  79  |  Port Shepstone ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=port+shepstone
# ------------------------
# Proceesing: City #  80  |  Placido de Castro BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=placido+de+castro
# ------------------------
# Proceesing: City #  81  |  Chabahar IR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=chabahar
# ------------------------
# Proceesing: City #  82  |  Coquimbo CL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=coquimbo
# ------------------------
# Proceesing: City #  83  |  Ajdabiya LY
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ajdabiya
# City not found, skipping...
# ------------------------
# Proceesing: City #  84  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=chokurdakh
# ------------------------
# Proceesing: City #  85  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=provideniya
# ------------------------
# Proceesing: City #  86  |  Derzhavinsk KZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=derzhavinsk
# ------------------------
# Proceesing: City #  87  |  Ukiah US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ukiah
# ------------------------
# Proceesing: City #  88  |  San Antonio CL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=san+antonio
# City not found, skipping...
# ------------------------
# Proceesing: City #  89  |  Sambava MG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sambava
# ------------------------
# Proceesing: City #  90  |  Genhe CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=genhe
# ------------------------
# Proceesing: City #  91  |  Sitka US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sitka
# ------------------------
# Proceesing: City #  92  |  Zvishavane ZW
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=zvishavane
# City not found, skipping...
# ------------------------
# Proceesing: City #  93  |  Kavieng PG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kavieng
# ------------------------
# Proceesing: City #  94  |  Ahipara NZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ahipara
# ------------------------
# Proceesing: City #  95  |  Mapalad PH
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mapalad
# ------------------------
# Proceesing: City #  96  |  Thunder Bay CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=thunder+bay
# ------------------------
# Proceesing: City #  97  |  Mango IT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mango
# ------------------------
# Proceesing: City #  98  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: City #  99  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  100  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  101  |  Mold GB
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mold
# ------------------------
# Proceesing: City #  102  |  Srednekolymsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=srednekolymsk
# ------------------------
# Proceesing: City #  103  |  Kosino RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kosino
# ------------------------
# Proceesing: City #  104  |  Saint Anthony US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=saint+anthony
# ------------------------
# Proceesing: City #  105  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  106  |  Clyde River CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=clyde+river
# ------------------------
# Proceesing: City #  107  |  Lakhdenpokhya RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lakhdenpokhya
# ------------------------
# Proceesing: City #  108  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=east+london
# ------------------------
# Proceesing: City #  109  |  Santa Maria del Oro MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=santa+maria+del+oro
# ------------------------
# Proceesing: City #  110  |  Turbat PK
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=turbat
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  111  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  112  |  Kaminokawa JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kaminokawa
# ------------------------
# Proceesing: City #  113  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: City #  114  |  Bonthe SL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bonthe
# ------------------------
# Proceesing: City #  115  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=dikson
# City not found, skipping...
# ------------------------
# Proceesing: City #  116  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nikolskoye
# ------------------------
# Proceesing: City #  117  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tuatapere
# City not found, skipping...
# ------------------------
# Proceesing: City #  118  |  Dullewala PK
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=dullewala
# ------------------------
# Proceesing: City #  119  |  Paamiut GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=paamiut
# City not found, skipping...
# ------------------------
# Proceesing: City #  120  |  Arraias BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=arraias
# ------------------------
# Proceesing: City #  121  |  Alice Springs AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=alice+springs
# City not found, skipping...
# ------------------------
# Proceesing: City #  122  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  123  |  Emerald AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=emerald
# ------------------------
# Proceesing: City #  124  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  125  |  Kimbe PG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kimbe
# ------------------------
# Proceesing: City #  126  |  Rapar IN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=rapar
# ------------------------
# Proceesing: City #  127  |  Peterhead AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=peterhead
# ------------------------
# Proceesing: City #  128  |  Upington ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=upington
# ------------------------
# Proceesing: City #  129  |  Pitsunda GE
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=pitsunda
# ------------------------
# Proceesing: City #  130  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hasaki
# ------------------------
# Proceesing: City #  131  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lavrentiya
# City not found, skipping...
# ------------------------
# Proceesing: City #  132  |  Gorontalo ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=gorontalo
# ------------------------
# Proceesing: City #  133  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  134  |  Alamosa US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=alamosa
# ------------------------
# Proceesing: City #  135  |  Cabo San Lucas MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=cabo+san+lucas
# ------------------------
# Proceesing: City #  136  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=esperance
# ------------------------
# Proceesing: City #  137  |  Ponta Delgada PT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ponta+delgada
# ------------------------
# Proceesing: City #  138  |  Lichuan CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lichuan
# ------------------------
# Proceesing: City #  139  |  Almaznyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=almaznyy
# ------------------------
# Proceesing: City #  140  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=leningradskiy
# ------------------------
# Proceesing: City #  141  |  Anadyr RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=anadyr
# ------------------------
# Proceesing: City #  142  |  Ilulissat GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ilulissat
# ------------------------
# Proceesing: City #  143  |  Nouakchott MR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nouakchott
# ------------------------
# Proceesing: City #  144  |  Tutoia BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tutoia
# ------------------------
# Proceesing: City #  145  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=port+elizabeth
# ------------------------
# Proceesing: City #  146  |  Havre-Saint-Pierre CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=havre-saint-pierre
# ------------------------
# Proceesing: City #  147  |  Xining CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=xining
# ------------------------
# Proceesing: City #  148  |  College US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=college
# ------------------------
# Proceesing: City #  149  |  Rapid Valley US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=rapid+valley
# ------------------------
# Proceesing: City #  150  |  Mragowo PL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mragowo
# ------------------------
# Proceesing: City #  151  |  Veraval FR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=veraval
# ------------------------
# Proceesing: City #  152  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=aklavik
# ------------------------
# Proceesing: City #  153  |  Marsa Matruh EG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=marsa+matruh
# ------------------------
# Proceesing: City #  154  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tasiilaq
# ------------------------
# Proceesing: City #  155  |  Pitimbu BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=pitimbu
# ------------------------
# Proceesing: City #  156  |  Gizo IL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=gizo
# ------------------------
# Proceesing: City #  157  |  Doha QA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=doha
# ------------------------
# Proceesing: City #  158  |  Coihaique CL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=coihaique
# ------------------------
# Proceesing: City #  159  |  Vigrestad NO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vigrestad
# ------------------------
# Proceesing: City #  160  |  Talara PE
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=talara
# ------------------------
# Proceesing: City #  161  |  Balabac PH
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=balabac
# ------------------------
# Proceesing: City #  162  |  Riyadh SA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=riyadh
# ------------------------
# Proceesing: City #  163  |  Inisa NG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=inisa
# ------------------------
# Proceesing: City #  164  |  Turayf SA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=turayf
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  165  |  Puerto Cabezas NI
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=puerto+cabezas
# City not found, skipping...
# ------------------------
# Proceesing: City #  166  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: City #  167  |  Coahuayana MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=coahuayana
# ------------------------
# Proceesing: City #  168  |  Hornslet DK
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hornslet
# ------------------------
# Proceesing: City #  169  |  Baykit RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=baykit
# ------------------------
# Proceesing: City #  170  |  Tautira PF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tautira
# ------------------------
# Proceesing: City #  171  |  Yulara AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=yulara
# ------------------------
# Proceesing: City #  172  |  Quatre Cocos MU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=quatre+cocos
# ------------------------
# Proceesing: City #  173  |  Piacabucu BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=piacabucu
# ------------------------
# Proceesing: City #  174  |  Suez EG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=suez
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  175  |  Nuuk GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nuuk
# ------------------------
# Proceesing: City #  176  |  Rongotea NZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=rongotea
# City not found, skipping...
# ------------------------
# Proceesing: City #  177  |  Mnogovershinnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mnogovershinnyy
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  178  |  Bridlington GB
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bridlington
# ------------------------
# Proceesing: City #  179  |  Rantauprapat ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=rantauprapat
# ------------------------
# Proceesing: City #  180  |  Colares PT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=colares
# ------------------------
# Proceesing: City #  181  |  Casper US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=casper
# ------------------------
# Proceesing: City #  182  |  Luderitz NA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=luderitz
# City not found, skipping...
# ------------------------
# Proceesing: City #  183  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  184  |  Guerrero Negro MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=guerrero+negro
# ------------------------
# Proceesing: City #  185  |  Bonavista CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bonavista
# ------------------------
# Proceesing: City #  186  |  Belmonte PT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=belmonte
# City not found, skipping...
# ------------------------
# Proceesing: City #  187  |  Dudinka RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=dudinka
# ------------------------
# Proceesing: City #  188  |  Karangasem ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=karangasem
# ------------------------
# Proceesing: City #  189  |  Cayenne GF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=cayenne
# City not found, skipping...
# ------------------------
# Proceesing: City #  190  |  Conneaut US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=conneaut
# ------------------------
# Proceesing: City #  191  |  Pierre US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=pierre
# ------------------------
# Proceesing: City #  192  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  193  |  Damietta EG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=damietta
# ------------------------
# Proceesing: City #  194  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=iqaluit
# ------------------------
# Proceesing: City #  195  |  Puerto Carreno CO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=puerto+carreno
# ------------------------
# Proceesing: City #  196  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  197  |  Vanimo PG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vanimo
# ------------------------
# Proceesing: City #  198  |  Broome GB
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=broome
# ------------------------
# Proceesing: City #  199  |  Katubao PH
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=katubao
# ------------------------
# Proceesing: City #  200  |  Kumo NG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kumo
# ------------------------
# Proceesing: City #  201  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: City #  202  |  Ciudad Bolivar VE
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ciudad+bolivar
# City not found, skipping...
# ------------------------
# Proceesing: City #  203  |  Nicoya CR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nicoya
# ------------------------
# Proceesing: City #  204  |  Bathsheba BB
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bathsheba
# ------------------------
# Proceesing: City #  205  |  Te Anau NZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=te+anau
# ------------------------
# Proceesing: City #  206  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=norman+wells
# ------------------------
# Proceesing: City #  207  |  Boulder City US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=boulder+city
# City not found, skipping...
# ------------------------
# Proceesing: City #  208  |  Paratinga BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=paratinga
# ------------------------
# Proceesing: City #  209  |  Iralaya HN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=iralaya
# City not found, skipping...
# ------------------------
# Proceesing: City #  210  |  Staryy Nadym RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=staryy+nadym
# ------------------------
# Proceesing: City #  211  |  Oranjemund ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=oranjemund
# ------------------------
# Proceesing: City #  212  |  Sibolga ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sibolga
# ------------------------
# Proceesing: City #  213  |  Hirara JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hirara
# ------------------------
# Proceesing: City #  214  |  Yandyki RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=yandyki
# ------------------------
# Proceesing: City #  215  |  Nioro GM
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nioro
# City not found, skipping...
# ------------------------
# Proceesing: City #  216  |  Ust-Omchug RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ust-omchug
# ------------------------
# Proceesing: City #  217  |  Pimentel BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=pimentel
# ------------------------
# Proceesing: City #  218  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mahebourg
# ------------------------
# Proceesing: City #  219  |  Shingu JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=shingu
# ------------------------
# Proceesing: City #  220  |  Libertador General San Martin AR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=libertador+general+san+martin
# ------------------------
# Proceesing: City #  221  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=pisco
# ------------------------
# Proceesing: City #  222  |  Portland US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=portland
# ------------------------
# Proceesing: City #  223  |  Oranjestad AW
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=oranjestad
# ------------------------
# Proceesing: City #  224  |  Dawlatabad AF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=dawlatabad
# ------------------------
# Proceesing: City #  225  |  La Spezia IT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=la+spezia
# City not found, skipping...
# ------------------------
# Proceesing: City #  226  |  Yumen CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=yumen
# ------------------------
# Proceesing: City #  227  |  San Lorenzo PY
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=san+lorenzo
# ------------------------
# Proceesing: City #  228  |  Jumla NP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=jumla
# City not found, skipping...
# ------------------------
# Proceesing: City #  229  |  Shuangyang CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=shuangyang
# ------------------------
# Proceesing: City #  230  |  Talnakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=talnakh
# ------------------------
# Proceesing: City #  231  |  Almeria ES
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=almeria
# ------------------------
# Proceesing: City #  232  |  Tooele US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tooele
# ------------------------
# Proceesing: City #  233  |  Olinda EC
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=olinda
# City not found, skipping...
# ------------------------
# Proceesing: City #  234  |  Ayagoz KZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ayagoz
# ------------------------
# Proceesing: City #  235  |  Ukhta RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ukhta
# ------------------------
# Proceesing: City #  236  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vila+franca+do+campo
# ------------------------
# Proceesing: City #  237  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=arraial+do+cabo
# ------------------------
# Proceesing: City #  238  |  Ketchikan US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ketchikan
# ------------------------
# Proceesing: City #  239  |  Roebourne AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=roebourne
# ------------------------
# Proceesing: City #  240  |  The Valley AI
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=the+valley
# ------------------------
# Proceesing: City #  241  |  Atambua ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=atambua
# ------------------------
# Proceesing: City #  242  |  Saldanha PT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=saldanha
# ------------------------
# Proceesing: City #  243  |  Angoche MZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=angoche
# ------------------------
# Proceesing: City #  244  |  Kaeo NZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kaeo
# ------------------------
# Proceesing: City #  245  |  Matara PE
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=matara
# ------------------------
# Proceesing: City #  246  |  Aykhal RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=aykhal
# ------------------------
# Proceesing: City #  247  |  Golden CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=golden
# ------------------------
# Proceesing: City #  248  |  Okakarara NA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=okakarara
# ------------------------
# Proceesing: City #  249  |  San Isidro PH
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=san+isidro
# ------------------------
# Proceesing: City #  250  |  Karlivka UA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=karlivka
# ------------------------
# Proceesing: City #  251  |  Seeboden AT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=seeboden
# ------------------------
# Proceesing: City #  252  |  Zhigansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=zhigansk
# ------------------------
# Proceesing: City #  253  |  Lompoc US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lompoc
# ------------------------
# Proceesing: City #  254  |  Tiksi RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tiksi
# ------------------------
# Proceesing: City #  255  |  Constitucion MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=constitucion
# ------------------------
# Proceesing: City #  256  |  Cam Ranh VN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=cam+ranh
# ------------------------
# Proceesing: City #  257  |  Albert FR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=albert
# ------------------------
# Proceesing: City #  258  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=cidreira
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  259  |  Moussoro TD
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=moussoro
# ------------------------
# Proceesing: City #  260  |  Vostok RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=vostok
# ------------------------
# Proceesing: City #  261  |  Hofn IS
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hofn
# ------------------------
# Proceesing: City #  262  |  Sikasso ML
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sikasso
# ------------------------
# Proceesing: City #  263  |  Kabanjahe ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kabanjahe
# ------------------------
# Proceesing: City #  264  |  Senanga ZM
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=senanga
# ------------------------
# Proceesing: City #  265  |  Yar-Sale RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=yar-sale
# ------------------------
# Proceesing: City #  266  |  Opuwo NA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=opuwo
# ------------------------
# Proceesing: City #  267  |  Kisangani CD
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kisangani
# ------------------------
# Proceesing: City #  268  |  Goderich CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=goderich
# ------------------------
# Proceesing: City #  269  |  La Ronge CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=la+ronge
# City not found, skipping...
# ------------------------
# Proceesing: City #  270  |  Port Keats AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=port+keats
# ------------------------
# Proceesing: City #  271  |  Miles City US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=miles+city
# ------------------------
# Proceesing: City #  272  |  Campoverde IT
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=campoverde
# ------------------------
# Proceesing: City #  273  |  Ponca City US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ponca+city
# ------------------------
# Proceesing: City #  274  |  Caravelas BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=caravelas
# ------------------------
# Proceesing: City #  275  |  San Andres PH
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=san+andres
# ------------------------
# Proceesing: City #  276  |  La Palma CO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=la+palma
# ------------------------
# Proceesing: City #  277  |  Lata IN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=lata
# ------------------------
# Proceesing: City #  278  |  Malpe IN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=malpe
# ------------------------
# Proceesing: City #  279  |  Puerto del Rosario ES
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=puerto+del+rosario
# ------------------------
# Proceesing: City #  280  |  Muros ES
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=muros
# ------------------------
# Proceesing: City #  281  |  Saint-Augustin FR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=saint-augustin
# City not found, skipping...
# ------------------------
# Proceesing: City #  282  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bethel
# ------------------------
# Proceesing: City #  283  |  Dingzhou CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=dingzhou
# ------------------------
# Proceesing: City #  284  |  Kollam IN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kollam
# ------------------------
# Proceesing: City #  285  |  Pahrump US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=pahrump
# ------------------------
# Proceesing: City #  286  |  Naze NG
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=naze
# ------------------------
# Proceesing: City #  287  |  Hokitika NZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hokitika
# ------------------------
# Proceesing: City #  288  |  Costa Rica MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=costa+rica
# ------------------------
# Proceesing: City #  289  |  Thinadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=thinadhoo
# ------------------------
# Proceesing: City #  290  |  Grants US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=grants
# City not found, skipping...
# ------------------------
# Proceesing: City #  291  |  Khuzhir RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=khuzhir
# City not found, skipping...
# ------------------------
# Proceesing: City #  292  |  Alexandria US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=alexandria
# ------------------------
# Proceesing: City #  293  |  Tiarei PF
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tiarei
# ------------------------
# Proceesing: City #  294  |  Port-Gentil GA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=port-gentil
# ------------------------
# Proceesing: City #  295  |  Bayonet Point US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bayonet+point
# ------------------------
# Proceesing: City #  296  |  Aksarka RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=aksarka
# ------------------------
# Proceesing: City #  297  |  Mukhen RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mukhen
# ------------------------
# Proceesing: City #  298  |  Kedrovyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kedrovyy
# ------------------------
# Proceesing: City #  299  |  Sisimiut GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sisimiut
# ------------------------
# Proceesing: City #  300  |  Kochi IN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=kochi
# ------------------------
# Proceesing: City #  301  |  Margate AU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=margate
# ------------------------
# Proceesing: City #  302  |  Touros BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=touros
# ------------------------
# Proceesing: City #  303  |  Ulaangom MN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ulaangom
# ------------------------
# Proceesing: City #  304  |  Una BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=una
# ------------------------
# Proceesing: City #  305  |  Alofi NU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=alofi
# ------------------------
# Proceesing: City #  306  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=carnarvon
# ------------------------
# Proceesing: City #  307  |  Beringovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=beringovskiy
# ------------------------
# Proceesing: City #  308  |  Nobeoka JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nobeoka
# ------------------------
# Proceesing: City #  309  |  Clive US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=clive
# ------------------------
# Proceesing: City #  310  |  Fairbanks US
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=fairbanks
# ------------------------
# Proceesing: City #  311  |  Sergeyevka KZ
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sergeyevka
# ------------------------
# Proceesing: City #  312  |  Udachnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=udachnyy
# ------------------------
# Proceesing: City #  313  |  Bima ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bima
# ------------------------
# Proceesing: City #  314  |  Anqiu CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=anqiu
# ------------------------
# Proceesing: City #  315  |  Namibe AO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=namibe
# ------------------------
# Proceesing: City #  316  |  Nara JP
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=nara
# ------------------------
# Proceesing: City #  317  |  Verkhoshizhemye RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=verkhoshizhemye
# ------------------------
# Proceesing: City #  318  |  Xingcheng CN
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=xingcheng
# ------------------------
# Proceesing: City #  319  |  Sola FI
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=sola
# ------------------------
# Proceesing: City #  320  |  Salekhard RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=salekhard
# ------------------------
# Proceesing: City #  321  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=san+patricio
# ------------------------
# Proceesing: City #  322  |  Laje BR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=laje
# ------------------------
# Proceesing: City #  323  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hithadhoo
# ------------------------
# Proceesing: City #  324  |  Verkhoyansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=verkhoyansk
# ------------------------
# Proceesing: City #  325  |  Venezuela CU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=venezuela
# ------------------------
# Proceesing: City #  326  |  Abu Zabad SD
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=abu+zabad
# ------------------------
# Proceesing: City #  327  |  Ryazanskaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ryazanskaya
# ------------------------
# Proceesing: City #  328  |  Arman RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=arman
# ------------------------
# Proceesing: City #  329  |  Manggar ID
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=manggar
# City not found, skipping...
# ------------------------
# Proceesing: City #  330  |  Mehamn NO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=mehamn
# ------------------------
# Proceesing: City #  331  |  Talcahuano CL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=talcahuano
# ------------------------
# Proceesing: City #  332  |  Fort Nelson CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=fort+nelson
# ------------------------
# Proceesing: City #  333  |  Ossora RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=ossora
# ------------------------
# Proceesing: City #  334  |  Tubinskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tubinskiy
# ------------------------
# Proceesing: City #  335  |  Narsaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=narsaq
# ------------------------
# Proceesing: City #  336  |  Inongo CD
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=inongo
# City not found, skipping...
# ------------------------
# Proceesing: City #  337  |  Port Hardy CA
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=port+hardy
# ------------------------
# Proceesing: City #  338  |  Hyeres FR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=hyeres
# ------------------------
# Proceesing: City #  339  |  Laguna MX
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=laguna
# ------------------------
# Proceesing: City #  340  |  Tilichiki RU
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tilichiki
# ------------------------
# Proceesing: City #  341  |  Bandarbeyla SO
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=bandarbeyla
# ------------------------
# Proceesing: City #  342  |  Coracora PE
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=coracora
# ------------------------
# Proceesing: City #  343  |  Tigre AR
# http://api.openweathermap.org/data/2.5/weather?appid=41f519e3bdb77b242447ddd82417ee63&units=IMPERIAL&q=tigre

# %%
clean_cities_df.count()

# %%
#Reset the index
clean_cities_df = clean_cities_df.reset_index()
del clean_cities_df['index']
clean_cities_df.head(25)

# %%
# Save data to a CSV file
clean_cities_df.to_csv("Weather_analysis/City_Data.csv")

# %% [markdown]
# ## Latitude vs. Temperature

# %%
#Build a scatter plot for Latitude vs. Temperature

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Temperature (F)"], c=clean_cities_df["Temperature (F)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-60, 120])

# Save the figure
plt.savefig("Weather_analysis/Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity (%)

# %%
#Build a scatter plot for Latitude vs. Humidity (%)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Humidity (%)"], c=clean_cities_df["Humidity (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='GnBu', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])

# Save the figure
plt.savefig("Weather_analysis/Latitude_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness (%)

# %%
#Build a scatter plot for Latitude vs. Cloudiness (%)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Cloudiness (%)"], c=clean_cities_df["Cloudiness (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='bone_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Cloudiness (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 125])

# Save the figure
plt.savefig("Weather_analysis/Latitude_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed (mph)

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Wind Speed (mph)"], c=clean_cities_df["Wind Speed (mph)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed (mph) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 50])

# Save the figure
plt.savefig("Weather_analysis/Latitude_WindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Longitude

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Longitude"], 
            clean_cities_df["Latitude"], c=clean_cities_df["Latitude"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='RdYlBu', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"Longitude vs. Latitude {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.grid(True)
plt.xlim([-200, 200])
plt.ylim([-80, 100])

# Save the figure
plt.savefig("Weather_analysis/Latitude_Longitude.png")

# Show plot
plt.show()
